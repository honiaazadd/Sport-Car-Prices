# %% [markdown]
# # Important Jupyter shortcut
# tab to give function methods
# shift&tab parameter and help
# command&/ to comment ⌘/: comment

# %% [markdown]
# # Cardio Good Fitness Case Study - Descriptive Statistics
# The market research team at AdRight is assigned the task to identify the profile of the typical customer for each treadmill product offered by CardioGood Fitness. The market research team decides to investigate whether there are differences across the product lines with respect to customer characteristics. The team decides to collect data on individuals who purchased a treadmill at a CardioGoodFitness retail store during the prior three months. The data are stored in the CardioGoodFitness.csv file.
#
# ### The team identifies the following customer variables to study:
#   - product purchased, TM195, TM498, or TM798;
#   - gender;
#   - age, in years;
#   - education, in years;
#   - relationship status, single or partnered;
#   - annual household income ;
#   - average number of times the customer plans to use the treadmill each week;
#   - average number of miles the customer expects to walk/run each week;
#   - and self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.
#
# ### Perform descriptive analytics to create a customer profile for each CardioGood Fitness treadmill product line.

# %%
# # Load the necessary packages
import pandas as pd #Visualization of data
import numpy as np  #multi demintional array

# %%
mydata = pd.read_csv('/content/Sport car price.csv')

# %%
mydata.tail(6) #bo hennaway 5 row kotaya deafultish har 5 ja
# Out:
#         Car_Make Car_Model  Year     Engine_Size Horsepower Torque PH_Time  \
# 1001     Bugatti    Chiron  2021               8       1479   1180     2.4
# 1002  Koenigsegg     Jesko  2022               5       1280   1106     2.5
# 1003       Lotus     Evija  2021  Electric Motor       1972   1254       2
# 1004     McLaren     Senna  2021               4        789    590     2.7
# 1005      Pagani    Huayra  2021               6        764    738       3
# 1006       Rimac    Nevera  2021  Electric Motor       1888   1696    1.85
#
#           Price
# 1001  3,000,000
# 1002  3,000,000
# 1003  2,000,000
# 1004  1,000,000
# 1005  2,600,000
# 1006  2,400,000

# %%
# Load the Cardio Dataset
mydata = pd.read_csv('/content/Sport car price.csv')

# %%
# mydata.head()
# mydata.columns
mydata.info() #zhmaray line 1007
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Car_Make     1007 non-null   object
#  1   Car_Model    1007 non-null   object
#  2   Year         1007 non-null   int64
#  3   Engine_Size  997 non-null    object
#  4   Horsepower   1007 non-null   object
#  5   Torque       1004 non-null   object
#  6   PH_Time      1007 non-null   object
#  7   Price        1007 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 63.1+ KB

# %%
mydata.describe()
# Out:
#               Year
# count  1007.000000
# mean   2021.201589
# std       2.019802
# min    1965.000000
# 25%    2021.000000
# 50%    2021.000000
# 75%    2022.000000
# max    2023.000000

# %%
Q1 = mydata["Year"].quantile(0.25)
Q3 = mydata["Year"].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt #Histogram drwsaka baw size
# %matplotlib inline

mydata.hist(figsize=(40,60))
plt.show()

# %%
import seaborn as sns #

sns.boxplot(x="Car_Model", y="Car_Make", data=mydata)
# Out:
# <Axes: xlabel='Car_Model', ylabel='Car_Make'>

# %%
pd.crosstab(mydata['Car_Make'],mydata['Engine_Size'] )
# Out:
# Engine_Size    -  0  1.5  1.5 + Electric  1.7  1.8   2  2.0 (Electric)  2.3  \
# Car_Make
# Acura          0  0    0               0    0    0   0               0    0
# Alfa Romeo     0  0    0               0    4    2   0               0    0
# Alpine         0  0    0               0    0    1   0               0    0
# Ariel          0  0    0               0    0    0   1               0    0
# Aston Martin   0  0    0               0    0    0   0               0    0
# Audi           0  0    0               0    0    0   0               0    0
# BMW            0  0    2               1    0    0   1               0    0
# Bentley        0  0    0               0    0    0   0               0    0
# Bugatti        0  0    0               0    0    0   0               0    0
# Chevrolet      0  0    0               0    0    0   0               0    0
# Dodge          0  0    0               0    0    0   0               0    0
# Ferrari        0  0    0               0    0    0   0               0    0
# Ford           0  0    0               0    0    0   0               0    1
# Jaguar         0  0    0               0    0    0   5               0    0
# Kia            0  0    0               0    0    0   0               0    0
# Koenigsegg     0  0    0               0    0    0   0               0    0
# Lamborghini    0  0    0               0    0    0   0               0    0
# Lexus          0  0    0               0    0    0   0               0    0
# Lotus          0  0    0               0    0    0   0               0    0
# Maserati       0  0    0               0    0    0   0               0    0
# Mazda          0  0    0               0    0    0   1               0    0
# McLaren        0  0    0               0    0    0   0               0    0
# Mercedes-AMG   0  0    0               0    0    0   0               0    0
# Mercedes-Benz  0  0    0               0    0    0   1               0    0
# Nissan         0  0    0               0    0    0   0               0    0
# Pagani         0  0    0               0    0    0   0               0    0
# Pininfarina    0  0    0               0    0    0   0               0    0
# Polestar       0  0    0               0    0    0   1               0    0
# Porsche        0  0    0               0    0    0  24               1    0
# Rimac          0  0    0               0    0    0   0               0    0
# Rolls-Royce    0  0    0               0    0    0   0               0    0
# Shelby         0  0    0               0    0    0   0               0    0
# Subaru         0  0    0               0    0    0   0               0    0
# TVR            0  0    0               0    0    0   0               0    0
# Tesla          1  1    0               0    0    0   0               0    0
# Toyota         0  0    0               0    0    0   0               0    0
# Ultima         0  0    0               0    0    0   0               0    0
# W Motors       0  0    0               0    0    0   0               0    0
#
# Engine_Size    2.5  ...  7   8  8.4  Electric  Electric (100 kWh)  \
# Car_Make            ...
# Acura            0  ...  0   0    0         0                   0
# Alfa Romeo       0  ...  0   0    0         0                   0
# Alpine           0  ...  0   0    0         0                   0
# Ariel            0  ...  0   0    0         0                   0
# Aston Martin     0  ...  0   0    0         0                   0
# Audi            20  ...  0   0    0         0                   0
# BMW              0  ...  0   0    0         0                   0
# Bentley          0  ...  0   0    0         0                   0
# Bugatti          0  ...  0  23    0         0                   0
# Chevrolet        0  ...  0   0    0         0                   0
# Dodge            0  ...  0   0    3         0                   0
# Ferrari          0  ...  0   0    0         0                   0
# Ford             0  ...  0   0    0         0                   0
# Jaguar           0  ...  0   0    0         0                   0
# Kia              0  ...  0   0    0         0                   0
# Koenigsegg       0  ...  0   0    0         0                   0
# Lamborghini      0  ...  0   0    0         0                   0
# Lexus            0  ...  0   0    0         0                   0
# Lotus            0  ...  0   0    0         4                   0
# Maserati         0  ...  0   0    0         1                   0
# Mazda            0  ...  0   0    0         0                   0
# McLaren          0  ...  0   0    0         0                   0
# Mercedes-AMG     0  ...  0   0    0         0                   0
# Mercedes-Benz    0  ...  0   0    0         0                   0
# Nissan           0  ...  0   0    0         0                   0
# Pagani           0  ...  0   0    0         0                   0
# Pininfarina      0  ...  0   0    0         2                   0
# Polestar         0  ...  0   0    0         0                   0
# Porsche          2  ...  0   0    0         8                   0
# Rimac            0  ...  0   0    0        10                   0
# Rolls-Royce      0  ...  0   0    0         0                   0
# Shelby           0  ...  1   0    0         0                   0
# Subaru           3  ...  0   0    0         0                   0
# TVR              0  ...  0   0    0         0                   0
# Tesla            0  ...  0   0    0        11                   1
# Toyota           0  ...  0   0    0         0                   0
# Ultima           0  ...  0   0    0         0                   0
# W Motors         0  ...  0   0    0         0                   0
#
# Engine_Size    Electric (93 kWh)  Electric (tri-motor)  Electric Motor  \
# Car_Make
# Acura                          0                     0               0
# Alfa Romeo                     0                     0               0
# Alpine                         0                     0               0
# Ariel                          0                     0               0
# Aston Martin                   0                     0               0
# Audi                           0                     0               0
# BMW                            0                     0               0
# Bentley                        0                     0               0
# Bugatti                        0                     0               0
# Chevrolet                      0                     0               0
# Dodge                          0                     0               0
# Ferrari                        0                     0               0
# Ford                           0                     0               0
# Jaguar                         0                     0               0
# Kia                            0                     0               0
# Koenigsegg                     0                     0               0
# Lamborghini                    0                     0               0
# Lexus                          0                     0               0
# Lotus                          0                     0               1
# Maserati                       0                     0               0
# Mazda                          0                     0               0
# McLaren                        0                     0               0
# Mercedes-AMG                   0                     0               0
# Mercedes-Benz                  0                     0               0
# Nissan                         0                     0               0
# Pagani                         0                     0               0
# Pininfarina                    0                     0               0
# Polestar                       0                     0               0
# Porsche                        1                     0               1
# Rimac                          0                     0               1
# Rolls-Royce                    0                     0               0
# Shelby                         0                     0               0
# Subaru                         0                     0               0
# TVR                            0                     0               0
# Tesla                          0                     1               0
# Toyota                         0                     0               0
# Ultima                         0                     0               0
# W Motors                       0                     0               0
#
# Engine_Size    Hybrid  Hybrid (4.0)
# Car_Make
# Acura               0             0
# Alfa Romeo          0             0
# Alpine              0             0
# Ariel               0             0
# Aston Martin        0             0
# Audi                0             0
# BMW                 1             0
# Bentley             0             0
# Bugatti             0             0
# Chevrolet           0             0
# Dodge               0             0
# Ferrari             0             0
# Ford                0             0
# Jaguar              0             0
# Kia                 0             0
# Koenigsegg          0             0
# Lamborghini         0             0
# Lexus               0             0
# Lotus               0             0
# Maserati            0             0
# Mazda               0             0
# McLaren             0             0
# Mercedes-AMG        0             0
# Mercedes-Benz       0             0
# Nissan              0             0
# Pagani              0             0
# Pininfarina         0             0
# Polestar            0             0
# Porsche             1             1
# Rimac               0             0
# Rolls-Royce         0             0
# Shelby              0             0
# Subaru              0             0
# TVR                 0             0
# Tesla               0             0
# Toyota              0             0
# Ultima              0             0
# W Motors            0             0
#
# [38 rows x 45 columns]

# %%
pd.crosstab(mydata['Car_Make'],mydata['Year'] )
# Out:
# Year           1965  2014  2015  2017  2019  2020  2021  2022  2023
# Car_Make
# Acura             0     0     0     0     0     0     9     7     0
# Alfa Romeo        0     0     0     0     0     6     6     4     0
# Alpine            0     0     0     0     0     0     1     0     0
# Ariel             0     0     0     0     0     0     1     0     0
# Aston Martin      0     0     0     0     0     0    35    15     0
# Audi              0     0     0     0     0     0    25    46     0
# BMW               0     0     0     0     0     1    10    52     0
# Bentley           0     0     0     0     0     0    16     9     0
# Bugatti           0     0     0     0     0     0    15     8     0
# Chevrolet         0     0     0     0     0     0    46    13     1
# Dodge             0     0     0     3     0     0    23    15     0
# Ferrari           0     0     0     0     0     0    37    18     0
# Ford              0     0     0     0     0     0    19    29     0
# Jaguar            0     0     0     0     0     0    12    18     0
# Kia               0     0     0     0     0     0     0     1     0
# Koenigsegg        0     0     0     0     0     0     6     9     0
# Lamborghini       0     0     0     0     0     3    60     3     0
# Lexus             0     0     0     0     0     0    13    13     0
# Lotus             0     0     0     0     0     1    28     6     0
# Maserati          0     0     0     0     1     2    16     6     0
# Mazda             0     0     0     0     0     0     1     0     0
# McLaren           0     0     0     0     1     5    53    16     0
# Mercedes-AMG      0     0     0     0     0     0     7     4     0
# Mercedes-Benz     0     2    10     0     1     1    33     7     0
# Nissan            0     0     0     0     0     5    31     0     1
# Pagani            0     0     0     0     0     1    10     1     0
# Pininfarina       0     0     0     0     0     0     1     1     0
# Polestar          0     0     0     0     0     0     1     0     0
# Porsche           0     0     1     0     0     0    37    50     0
# Rimac             0     0     0     0     0     0     5     9     0
# Rolls-Royce       0     0     0     0     0     0     9     1     0
# Shelby            1     0     0     0     0     0     0     0     0
# Subaru            0     0     0     0     0     0     2     1     0
# TVR               0     0     0     0     0     0     1     1     0
# Tesla             0     0     0     0     0     0     5    13     1
# Toyota            0     0     0     0     0     0     1     4     0
# Ultima            0     0     0     0     0     0     1     0     0
# W Motors          0     0     1     0     0     0     0     2     0

# %%
sns.countplot(x="Car_Model", hue="Year", data=mydata)
# Out:
# <Axes: xlabel='Car_Model', ylabel='count'>

# %%
pd.pivot_table(mydata,'Year', index=['Car_Model', 'Car_Make'],
                     columns=[ 'Price'])
# Out:
# Price                    1,000,000  1,050,000  1,500,000  1,550,000  \
# Car_Model   Car_Make
# 1           Polestar           NaN        NaN        NaN        NaN
# 370Z        Nissan             NaN        NaN        NaN        NaN
# 370Z Coupe  Nissan             NaN        NaN        NaN        NaN
# 370Z Nismo  Nissan             NaN        NaN        NaN        NaN
# 400Z        Nissan             NaN        NaN        NaN        NaN
# ...                            ...        ...        ...        ...
# WRX STI     Subaru             NaN        NaN        NaN        NaN
# Wraith      Rolls-Royce        NaN        NaN        NaN        NaN
# Z4 M40i     BMW                NaN        NaN        NaN        NaN
# Z4 Roadster BMW                NaN        NaN        NaN        NaN
# i8          BMW                NaN        NaN        NaN        NaN
#
# Price                    1,700,000  1,800,000  100,000  100,200  100,450  \
# Car_Model   Car_Make
# 1           Polestar           NaN        NaN      NaN      NaN      NaN
# 370Z        Nissan             NaN        NaN      NaN      NaN      NaN
# 370Z Coupe  Nissan             NaN        NaN      NaN      NaN      NaN
# 370Z Nismo  Nissan             NaN        NaN      NaN      NaN      NaN
# 400Z        Nissan             NaN        NaN      NaN      NaN      NaN
# ...                            ...        ...      ...      ...      ...
# WRX STI     Subaru             NaN        NaN      NaN      NaN      NaN
# Wraith      Rolls-Royce        NaN        NaN      NaN      NaN      NaN
# Z4 M40i     BMW                NaN        NaN      NaN      NaN      NaN
# Z4 Roadster BMW                NaN        NaN      NaN      NaN      NaN
# i8          BMW                NaN        NaN      NaN      NaN      NaN
#
# Price                    100,500  ...  93,000  93,050  94,000  96,000  96,250  \
# Car_Model   Car_Make              ...
# 1           Polestar         NaN  ...     NaN     NaN     NaN     NaN     NaN
# 370Z        Nissan           NaN  ...     NaN     NaN     NaN     NaN     NaN
# 370Z Coupe  Nissan           NaN  ...     NaN     NaN     NaN     NaN     NaN
# 370Z Nismo  Nissan           NaN  ...     NaN     NaN     NaN     NaN     NaN
# 400Z        Nissan           NaN  ...     NaN     NaN     NaN     NaN     NaN
# ...                          ...  ...     ...     ...     ...     ...     ...
# WRX STI     Subaru           NaN  ...     NaN     NaN     NaN     NaN     NaN
# Wraith      Rolls-Royce      NaN  ...     NaN     NaN     NaN     NaN     NaN
# Z4 M40i     BMW              NaN  ...     NaN     NaN     NaN     NaN     NaN
# Z4 Roadster BMW              NaN  ...     NaN     NaN     NaN     NaN     NaN
# i8          BMW              NaN  ...     NaN     NaN     NaN     NaN     NaN
#
# Price                    96,950  98,395  99,000  99,800  99,990
# Car_Model   Car_Make
# 1           Polestar        NaN     NaN     NaN     NaN     NaN
# 370Z        Nissan          NaN     NaN     NaN     NaN     NaN
# 370Z Coupe  Nissan          NaN     NaN     NaN     NaN     NaN
# 370Z Nismo  Nissan          NaN     NaN     NaN     NaN     NaN
# 400Z        Nissan          NaN     NaN     NaN     NaN     NaN
# ...                         ...     ...     ...     ...     ...
# WRX STI     Subaru          NaN     NaN     NaN     NaN     NaN
# Wraith      Rolls-Royce     NaN     NaN     NaN     NaN     NaN
# Z4 M40i     BMW             NaN     NaN     NaN     NaN     NaN
# Z4 Roadster BMW             NaN     NaN     NaN     NaN     NaN
# i8          BMW             NaN     NaN     NaN     NaN     NaN
#
# [178 rows x 367 columns]

# %%
mydata['Year'].std()
# Out:
# 2.0198019354985264

# %%
mydata['Year'].mean()
# Out:
# np.float64(2021.201588877855)

# %%
sns.displot(mydata['Year'])

# %%
mydata.hist(by='Year',column = 'Car_Make')
# Out:
# array([[<Axes: title={'center': '1965'}>,
#         <Axes: title={'center': '2014'}>,
#         <Axes: title={'center': '2015'}>],
#        [<Axes: title={'center': '2017'}>,
#         <Axes: title={'center': '2019'}>,
#         <Axes: title={'center': '2020'}>],
#        [<Axes: title={'center': '2021'}>,
#         <Axes: title={'center': '2022'}>,
#         <Axes: title={'center': '2023'}>]], dtype=object)

# %%
mydata.hist(by='Year',column = 'Car_Model')
# Out:
# array([[<Axes: title={'center': '1965'}>,
#         <Axes: title={'center': '2014'}>,
#         <Axes: title={'center': '2015'}>],
#        [<Axes: title={'center': '2017'}>,
#         <Axes: title={'center': '2019'}>,
#         <Axes: title={'center': '2020'}>],
#        [<Axes: title={'center': '2021'}>,
#         <Axes: title={'center': '2022'}>,
#         <Axes: title={'center': '2023'}>]], dtype=object)

# %%
mydata.hist(by='Year',column = 'Car_Make')
# Out:
# array([[<Axes: title={'center': '1965'}>,
#         <Axes: title={'center': '2014'}>,
#         <Axes: title={'center': '2015'}>],
#        [<Axes: title={'center': '2017'}>,
#         <Axes: title={'center': '2019'}>,
#         <Axes: title={'center': '2020'}>],
#        [<Axes: title={'center': '2021'}>,
#         <Axes: title={'center': '2022'}>,
#         <Axes: title={'center': '2023'}>]], dtype=object)

# %%
mydata.hist(by='Year',column = 'Horsepower', figsize=(20,30))
# Out:
# array([[<Axes: title={'center': '1965'}>,
#         <Axes: title={'center': '2014'}>,
#         <Axes: title={'center': '2015'}>],
#        [<Axes: title={'center': '2017'}>,
#         <Axes: title={'center': '2019'}>,
#         <Axes: title={'center': '2020'}>],
#        [<Axes: title={'center': '2021'}>,
#         <Axes: title={'center': '2022'}>,
#         <Axes: title={'center': '2023'}>]], dtype=object)

# %%
sns.pairplot(mydata)

# %% [markdown]
# <style>
#   ul {
#     background-color: black;
#   }
#
# <div>
# <span style="color: pink;">
# <h2> Project: concider specification of your dataset </h2>
#     <h3>
#     <ul>
#   <li>Apply all above codes</li>
#   <li>Allways be creative to find interested information</li>
#   <li> Arrange and clean up your GitHub</li>
#     </ul>
#     </h3>
# </div>
#     </style>

# %% [markdown]
# <ul style="background-color: gray;">
#     <div style="color: yalow;font-size: 46px>
#   <li>analyze</li>
#   <li>create</li>
#                 </div>
# </ul>

# %% [markdown]
# <div style="background-color: lightgreen; padding: 10px; text-align: center;">
#   <h2 style="color: green;">Project: Consider the Features of Your Dataset</h2>
#   <ol style="background-color: black; color: gold; font-size: 22px; line-height: 1.5; margin-left: 10px;text-align:left">
#     <li>Apply all codes</li>
#     <li>Always be creative and find interesting information</li>
#     <li>Arrange and clean up your GitHub</li>
#     <li>Take the chance and strengthen the spirit of teamwork</li>
#   </ol>
# </div>

# %% [markdown]
# <center>
# <span style="color: blue; font-size: 46px; font-weight: bold; text-decoration: underline;">
# <h1> Lab Work </h1>
# </center>

# %% [markdown]
# <div>
# <span style="color: yellow; font-size: 46px;>
#  <h2>LabWork 1: </h2>
# </div>
# Calculate qty of products for usage 4

# %% [markdown]
# <center>
# <span style="color: green; font-size: 16px;">
# <h1> Lab Work 1: </h1>
# </center>
# Create a cross-tabulation table between the "Product" column and a single value of the "Usage"  column of value 4 in the mydata DataFrame.

# %% [markdown]
# <center>
# <span style="color: green; font-size: 16px;">
# <h1> Lab Work 2: </h1>
# </center>
# Use pivot_table function from the Pandas library to create a pivot table from the mydata DataFrame. The resulting table should have the following features:
#
# 1. The rows of the table will be grouped by the "Product" and "MaritalStatus" columns.
# 2. The columns of the table will be grouped by the "Gender" column.
# 3. The values in the table will be the count of occurrences for each combination of row and column.

# %% [markdown]
# <center>
# <span style="color: green; font-size: 16px;">
# <h1> Lab Work 3: </h1>
# </center>
# Use the hist function from the Pandas library to create a histogram of the "Usage" column in the mydata DataFrame, grouped by the "Gender" column.

# %% [markdown]
# <div>
#     <span style="color: green;">
#     Below cell contains the code of LabWork 1 in white;
# </div>

# %% [markdown]
# <div>
# <span style="color: white; font-size: 16px;">
#
#
# # LabWork 1
# pd.crosstab(mydata['Product'],mydata['Usage'][4] )
# </div>

# %%
pd.crosstab(mydata['Car_Make'],mydata['Year'][5] )
# Out:
# col_0          2022
# Car_Make
# Acura            16
# Alfa Romeo       16
# Alpine            1
# Ariel             1
# Aston Martin     50
# Audi             71
# BMW              63
# Bentley          25
# Bugatti          23
# Chevrolet        60
# Dodge            41
# Ferrari          55
# Ford             48
# Jaguar           30
# Kia               1
# Koenigsegg       15
# Lamborghini      66
# Lexus            26
# Lotus            35
# Maserati         25
# Mazda             1
# McLaren          75
# Mercedes-AMG     11
# Mercedes-Benz    54
# Nissan           37
# Pagani           12
# Pininfarina       2
# Polestar          1
# Porsche          88
# Rimac            14
# Rolls-Royce      10
# Shelby            1
# Subaru            3
# TVR               2
# Tesla            19
# Toyota            5
# Ultima            1
# W Motors          3

# %% [markdown]
# <div>
#     <span style="color: green;">
#     Below cell contains the code of LabWork 2 in white;
# </div>

# %% [markdown]
# <div>
# <span style="color: white; font-size: 16px;">
#
#
# # LabWork 2
# pd.pivot_table(mydata, index=['Product', 'MaritalStatus'],
#                      columns=[ 'Gender'], aggfunc=len)
#                      </div>

# %%
pd.pivot_table(mydata, index=['Car_Make', 'Year'], columns=[ 'Price'], aggfunc=len)
# Out:
#                 Car_Model                                                    \
# Price           1,000,000 1,050,000 1,500,000 1,550,000 1,700,000 1,800,000
# Car_Make   Year
# Acura      2021       NaN       NaN       NaN       NaN       NaN       NaN
#            2022       NaN       NaN       NaN       NaN       NaN       NaN
# Alfa Romeo 2020       NaN       NaN       NaN       NaN       NaN       NaN
#            2021       NaN       NaN       NaN       NaN       NaN       NaN
#            2022       NaN       NaN       NaN       NaN       NaN       NaN
# ...                   ...       ...       ...       ...       ...       ...
# Toyota     2021       NaN       NaN       NaN       NaN       NaN       NaN
#            2022       NaN       NaN       NaN       NaN       NaN       NaN
# Ultima     2021       NaN       NaN       NaN       NaN       NaN       NaN
# W Motors   2015       NaN       NaN       NaN       NaN       NaN       NaN
#            2022       NaN       NaN       NaN       1.0       1.0       NaN
#
#                                                  ... Torque                \
# Price           100,000 100,200 100,450 100,500  ... 93,000 93,050 94,000
# Car_Make   Year                                  ...
# Acura      2021     NaN     NaN     NaN     NaN  ...    NaN    NaN    NaN
#            2022     NaN     NaN     NaN     NaN  ...    NaN    NaN    NaN
# Alfa Romeo 2020     NaN     NaN     NaN     NaN  ...    NaN    NaN    NaN
#            2021     NaN     NaN     NaN     NaN  ...    NaN    NaN    NaN
#            2022     NaN     NaN     NaN     NaN  ...    NaN    NaN    NaN
# ...                 ...     ...     ...     ...  ...    ...    ...    ...
# Toyota     2021     NaN     NaN     NaN     NaN  ...    NaN    NaN    NaN
#            2022     NaN     NaN     NaN     NaN  ...    NaN    NaN    NaN
# Ultima     2021     NaN     NaN     NaN     NaN  ...    NaN    NaN    NaN
# W Motors   2015     NaN     NaN     NaN     NaN  ...    NaN    NaN    NaN
#            2022     NaN     NaN     NaN     NaN  ...    NaN    NaN    NaN
#
#
# Price           96,000 96,250 96,950 98,395 99,000 99,800 99,990
# Car_Make   Year
# Acura      2021    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#            2022    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Alfa Romeo 2020    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#            2021    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#            2022    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...                ...    ...    ...    ...    ...    ...    ...
# Toyota     2021    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#            2022    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Ultima     2021    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# W Motors   2015    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#            2022    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [87 rows x 1835 columns]

# %% [markdown]
# <div>
#     <span style="color: green;">
#     Below cell contains the code of LabWork 3 in white;
# </div>

# %% [markdown]
# <div>
# <span style="color: white; font-size: 16px;">
#
#
# # LabWork 3
# mydata.hist(by='Gender',column = 'Usage')
#     </div>

# %%
mydata.hist(by='Year',column = 'Car_Model')
# Out:
# array([[<Axes: title={'center': '1965'}>,
#         <Axes: title={'center': '2014'}>,
#         <Axes: title={'center': '2015'}>],
#        [<Axes: title={'center': '2017'}>,
#         <Axes: title={'center': '2019'}>,
#         <Axes: title={'center': '2020'}>],
#        [<Axes: title={'center': '2021'}>,
#         <Axes: title={'center': '2022'}>,
#         <Axes: title={'center': '2023'}>]], dtype=object)
